# %% [markdown]
# ## JSON IN PYTHON PRACTICE

# %% [markdown]
# from json to python -> load()[Read a json file] and loads()[read a json strings to a dictoanry]\
# from python to json -> dunmp() and dunps()\
# ![image.png](attachment:image.png)

# %%
import json

employee ='{"name": "Nitin", "department":"Finance",\
"company":"GFG"}'

employee_dict = json.loads(employee)
print(employee_dict)

for key , value in employee_dict.items():
    print(f"{key} : {value}")
    
print(employee_dict['department'])
# Out:
# {'name': 'Nitin', 'department': 'Finance', 'company': 'GFG'}
# name : Nitin
# department : Finance
# company : GFG
# Finance

# %%
# Opening JSON file
f = open('file.json',)

# returns JSON object as
# a dictionary
data = json.load(f)

# Iterating through the json
# list
for i in data:
    for key , value in i.items():
        print(f"{key}: {value}")
    print()

# Closing file
f.close()
# Out:
# productId: 101
# productName: Wireless Mouse
# price: 25.99
# inStock: True
#
# productId: 102
# productName: Keyboard
# price: 45.99
# inStock: False

# %%
dictioanry = {
    "name": "sunil",
    "department": "HR",
    "Company": 'GFG'
}

# json_object = json.dumps(dictioanry)
# print(json_object)

json_file = "sample.json"

with open(json_file , 'w') as file:
    json.dump(dictioanry , file)

# %%
json_data = '[ {"studentid": 1, "name": "Nikhil", "subjects":\
["Python", "Data Structures"], "company":"GFG"},\
{"studentid": 2, "name": "Nisha", "subjects":\
["Java", "C++", "R Lang"], "company":"GFG"} ]'

data = json.loads(json_data)

data_formatted = json.dumps(data , indent=4 , sort_keys=True)

print(data , "\n")
print(data_formatted)
# Out:
# [{'studentid': 1, 'name': 'Nikhil', 'subjects': ['Python', 'Data Structures'], 'company': 'GFG'}, {'studentid': 2, 'name': 'Nisha', 'subjects': ['Java', 'C++', 'R Lang'], 'company': 'GFG'}]
#
# [
#     {
#         "company": "GFG",
#         "name": "Nikhil",
#         "studentid": 1,
#         "subjects": [
#             "Python",
#             "Data Structures"
#         ]
#     },
#     {
#         "company": "GFG",
#         "name": "Nisha",
#         "studentid": 2,
#         "subjects": [
#             "Java",
#             "C++",
#             "R Lang"
#         ]
#     }
# ]
